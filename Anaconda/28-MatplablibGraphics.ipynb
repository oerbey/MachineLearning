# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
numpyArray1 = np.linspace(0,10,20)

# %%
numpyArray2 = numpyArray1 ** 2

# %%
(myFig, myAxis) = pyt.subplots()
myAxis.plot(numpyArray1, numpyArray2, "g", alpha = 0.3) # alpha adds transparancy 
myAxis.plot(numpyArray2, numpyArray1, color = "#b99eff")

# %%
(newFig, newAxis) = pyt.subplots()
newAxis.plot(numpyArray1, numpyArray1 + 2, color = "blue", linewidth = 5.0)
newAxis.plot(numpyArray1, numpyArray1 + 3, color = "red")

newAxis.plot(numpyArray1, numpyArray1 + 4, color = "#262a1a", linestyle = "-.", linewidth = 8.0)
#linestyle = "--" / ":" / 

newAxis.plot(numpyArray1, numpyArray1 + 7, color = "#99a969", linestyle = "-.", linewidth = 6.0, marker = "o", markersize = 8, markerfacecolor = "Red")

# %% [markdown]
# ## Scatter

# %%
plt.scatter(numpyArray1, numpyArray2)

# %% [markdown]
# ## Histogram

# %%
newArray = np.random.randint(0,100,50)

# %%
plt.hist(newArray)
# Out:
# (array([5., 6., 3., 2., 6., 2., 7., 5., 7., 7.]),
#  array([ 2. , 11.7, 21.4, 31.1, 40.8, 50.5, 60.2, 69.9, 79.6, 89.3, 99. ]),
#  <BarContainer object of 10 artists>)

# %% [markdown]
# ## Boxplot

# %%
plt.boxplot(newArray)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x7fabb12f08b0>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x7fabb12eaac0>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x7fabb12f0250>],
#  'medians': [<matplotlib.lines.Line2D at 0x7fabb12d9190>],
#  'fliers': [<matplotlib.lines.Line2D at 0x7fabb12d9be0>],
#  'means': []}
